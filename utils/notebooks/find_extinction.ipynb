# %%
from __future__ import print_function

try:
    from importlib import reload
except:
    pass

# %matplotlib inline

from matplotlib import pyplot as plt

import os
import warnings

import numpy as np
import pandas as pd
import astropy as ap

from astropy import units as u

from LSST_tools.utils import *

# %%
import sfdmap

m = sfdmap.SFDMap()

# %%
m.ebv(0., 0., unit = "radian")
# Out:
# 0.027364157827046782

# %%
df = generate_coordinates(100)

# %%
df["EBV"] = m.ebv(df["theta"], df["phi"], unit = "radian")

# %%
df
# Out:
#          phi     theta       EBV
# 0  -0.372152  0.423073  0.013680
# 1  -0.449109  2.933169  0.045799
# 2  -0.218382  1.299547  0.116623
# 3  -1.058269  2.075935  0.170342
# 4  -0.433346 -1.501663  1.068188
# 5  -0.558015 -1.585313  0.895840
# 6  -0.631911 -2.051130  0.470642
# 7  -1.096614  2.451137  0.203516
# 8  -1.055260  3.113355  1.129303
# 9  -0.684418 -0.662798  0.027691
# 10 -0.508057 -1.089721  0.140053
# 11 -0.469607  2.983062  0.052422
# 12 -0.478105  2.076330  0.683174
# 13 -0.775412  2.110977  0.338537
# 14 -0.921816  0.571997  0.017812
# 15 -0.562543 -2.354461  0.153764
# 16 -0.213528 -0.059008  0.028735
# 17 -0.930802  2.248858  0.395221
# 18 -0.571966 -0.730455  0.080217
# 19 -1.242589  1.170772  0.103392
# 20 -0.365602  0.072653  0.015211
# 21 -0.834537  1.430838  0.027000
# 22 -0.276386  1.861754  0.544113
# 23 -0.973575 -2.330080  2.210705
# 24 -0.663651  2.402808  0.276882
# 25 -1.051488 -0.885306  0.050851
# 26 -1.147191 -1.557636  0.053187
# 27 -0.385353  2.350326  0.155048
# 28 -0.247529  2.323037  0.040882
# 29 -0.237226 -0.735201  0.041589
# ..       ...       ...       ...
# 70 -0.741798  1.042468  0.004098
# 71 -1.209966  2.869325  0.183775
# 72 -0.725219  0.593548  0.013646
# 73 -0.565072  1.559222  0.025774
# 74 -0.459084  1.487428  0.023700
# 75 -0.934502  1.650854  0.083758
# 76 -1.357135  0.104050  0.047901
# 77 -0.736776  1.175528  0.021245
# 78 -0.340598  2.214004  0.083037
# 79 -0.833297  1.286813  0.010852
# 80 -0.361800 -3.058757  0.047320
# 81 -0.397792 -1.991272  1.032740
# 82 -1.296472 -0.779794  0.048055
# 83 -0.861180 -1.156668  0.062120
# 84 -0.211977 -0.256775  0.037719
# 85 -0.882592  2.734160  0.233089
# 86 -1.212354  1.337235  0.168794
# 87 -1.042953 -2.733670  1.111427
# 88 -0.471032  2.000600  0.759451
# 89 -0.442328 -1.367807  0.289768
# 90 -1.018605  0.850629  0.018416
# 91 -0.736937  3.123680  0.132469
# 92 -0.217065 -2.741566  0.052389
# 93 -1.147993 -0.616824  0.028995
# 94 -0.290578  2.695499  0.065403
# 95 -0.356511 -2.145634  0.173229
# 96 -1.353227  1.597912  0.085602
# 97 -0.599161  1.823311  0.198607
# 98 -0.361149  2.640367  0.049664
# 99 -1.315267 -0.763923  0.053056
#
# [100 rows x 3 columns]

# %%
generate_coordinates
# Out:
# <function LSST_tools.utils.generate_coordinates>
